# %%
# plot accuracies - $\lambda_n$ - SNR Levels
import matplotlib.pyplot as plt
import numpy as np

snr_levels = [20, 30, 40, 50, 60, 70, 80, 90,100]
lambda_n_values = [0.05, 0.06, 0.07, 0.08, 0.09, 0.1, 0.2, 0.3, 0.4]

accuracy_data = [
    [0.9407805800437927, 0.9270110130310059, 0.9158726334571838, 0.9038050770759583, 0.8919538259506226, 0.8802427649497986, 0.7698158621788025, 0.6662018895149231, 0.5680977702140808],  # SNR = 20dB
    [0.9459779858589172, 0.9343749880790713, 0.9235191345214844, 0.9121714830398562, 0.9016482830047607, 0.8898597955703735, 0.7817989587783813, 0.6791615486145023, 0.5780489444732666],  # SNR = 30dB
    [0.9522098302841187, 0.9415680766105652, 0.9307484626770023, 0.9207003116607666, 0.9100272059440613, 0.8992675542831421, 0.7912074327468872, 0.6865631937980652, 0.5842766165733337],  # SNR = 40dB
    [0.9585742354393005, 0.9486370086669922, 0.9376848340034485, 0.9276060461997986, 0.9164397120475769, 0.9064201712608337, 0.7992403507232666, 0.6930322051048279, 0.5890367031097412], # SNR = 50dB
    [0.9629952311515808, 0.9523967504501343, 0.9430824518203735, 0.9334605336189272, 0.9208921790122986, 0.9111781716346741, 0.8033747076988224, 0.6968638300895691, 0.5925781130790713], # SNR = 60dB
    [0.9649260640144348, 0.9542466402053833, 0.9455175995826721, 0.9346289038658142, 0.9253690242767334, 0.9147663116455078, 0.8057003617286682, 0.6971805095672607, 0.5919566154479985], # SNR = 70dB
    [0.9651639461517334, 0.9549455642700195, 0.9440882802009583, 0.9338567256927493, 0.9247614145278931, 0.9139167070388794, 0.8067543506622314, 0.6994628906252356, 0.5915736556053162], # SNR = 80dB
    [0.9646135568618774, 0.9553354978561401, 0.9452595114707947, 0.9354059696197513, 0.9241594672203064, 0.9138162732124329, 0.8059821724891663, 0.6968240737915039, 0.5929241180419922],  # SNR = 90dB
    [0.9649121165275574, 0.9530803561210632, 0.9456368684768677, 0.9338434934616089, 0.9249832630157471, 0.9131605625152588, 0.8053843379020691, 0.6981661319732666, 0.5920828580856323]  # SNR = 100dB
]


accuracy_data_transposed = np.array(accuracy_data).T.tolist()

plt.figure(figsize=(10, 8))
markers = ['o', 's', 'v', '^', 'H', 'x', 'p', 'd','*']

for i in range(9):
    plt.plot(snr_levels, accuracy_data_transposed[i], label=f'$\lambda_n$ = {lambda_n_values[i]}', marker=markers[i], linestyle='--')

plt.xlabel('SNR (dB)')
plt.ylabel('Accuracy [%]')
plt.title('Model accuracies under Different $\lambda_n$ and SNR Levels')
plt.legend()
plt.grid(True, linestyle='--')
plt.ylim(0.55, 1.0)
plt.show()

# %%
# plot roc_curve
import scipy.io as sio
from sklearn.metrics import PrecisionRecallDisplay, RocCurveDisplay, auc, roc_curve
import matplotlib.pyplot as plt
fpr,tpr,roc_auc = dict(),dict(),dict()

roc_data005 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.05.mat')
fpr['0.05'] = roc_data005['fpr'][0][0][0][0]
tpr['0.05'] = roc_data005['tpr'][0][0][0][0]
roc_auc['0.05'] = roc_data005['roc_auc'][0][0][0][0][0]

roc_data006 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.06.mat')
fpr['0.06'] = roc_data006['fpr'][0][0][0][0]
tpr['0.06'] = roc_data006['tpr'][0][0][0][0]
roc_auc['0.06'] = roc_data006['roc_auc'][0][0][0][0][0]

roc_data007 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.07.mat')
fpr['0.07'] = roc_data007['fpr'][0][0][0][0]
tpr['0.07'] = roc_data007['tpr'][0][0][0][0]
roc_auc['0.07'] = roc_data007['roc_auc'][0][0][0][0][0]

roc_data008 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.08.mat')
fpr['0.08'] = roc_data008['fpr'][0][0][0][0]
tpr['0.08'] = roc_data008['tpr'][0][0][0][0]
roc_auc['0.08'] = roc_data008['roc_auc'][0][0][0][0][0]

roc_data009 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.09.mat')
fpr['0.09'] = roc_data009['fpr'][0][0][0][0]
tpr['0.09'] = roc_data009['tpr'][0][0][0][0]
roc_auc['0.09'] = roc_data009['roc_auc'][0][0][0][0][0]

roc_data01 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.1.mat')
fpr['0.1'] = roc_data01['fpr'][0][0][0][0]
tpr['0.1'] = roc_data01['tpr'][0][0][0][0]
roc_auc['0.1'] = roc_data01['roc_auc'][0][0][0][0][0]

roc_data02 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.2.mat')
fpr['0.2'] = roc_data02['fpr'][0][0][0][0]
tpr['0.2'] = roc_data02['tpr'][0][0][0][0]
roc_auc['0.2'] = roc_data02['roc_auc'][0][0][0][0][0]

roc_data03 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.3.mat')
fpr['0.3'] = roc_data03['fpr'][0][0][0][0]
tpr['0.3'] = roc_data03['tpr'][0][0][0][0]
roc_auc['0.3'] = roc_data03['roc_auc'][0][0][0][0][0]

roc_data04 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/roc_auc_Co-60_0.4.mat')
fpr['0.4'] = roc_data04['fpr'][0][0][0][0]
tpr['0.4'] = roc_data04['tpr'][0][0][0][0]
roc_auc['0.4'] = roc_data04['roc_auc'][0][0][0][0][0]
for key in fpr.keys():
    plt.plot(
        fpr[key],
        tpr[key],
        label=f"ROC curve (AUC = {roc_auc[key]:.2f} $\lambda_n$ = {key})",
        linewidth=1,
    )
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Micro-average Receiver Operating Characteristic under different $\lambda_n$')
plt.legend()
plt.savefig('/root/WorkSpace/project/spectrum_two_stage/results/roc_curve.png',dpi=300)
plt.close()

# %%
# plot pr_curve

import scipy.io as sio
import matplotlib.pyplot as plt
precision, recall, average_precision= dict(),dict(),dict()
pr_data_005 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.05.mat')
precision['0.05'] = pr_data_005['precision'][0][0][0][0]
recall['0.05'] = pr_data_005['recall'][0][0][0][0]
average_precision['0.05'] = pr_data_005['average_precision'][0][0][0][0][0]

pr_data_006 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.06.mat')
precision['0.06'] = pr_data_006['precision'][0][0][0][0]
recall['0.06'] = pr_data_006['recall'][0][0][0][0]
average_precision['0.06'] = pr_data_006['average_precision'][0][0][0][0][0]

pr_data_007 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.07.mat')
precision['0.07'] = pr_data_007['precision'][0][0][0][0]
recall['0.07'] = pr_data_007['recall'][0][0][0][0]
average_precision['0.07'] = pr_data_007['average_precision'][0][0][0][0][0]

pr_data_008 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.08.mat')
precision['0.08'] = pr_data_008['precision'][0][0][0][0]
recall['0.08'] = pr_data_008['recall'][0][0][0][0]
average_precision['0.08'] = pr_data_008['average_precision'][0][0][0][0][0]

pr_data_009 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.09.mat')
precision['0.09'] = pr_data_009['precision'][0][0][0][0]
recall['0.09'] = pr_data_009['recall'][0][0][0][0]
average_precision['0.09'] = pr_data_009['average_precision'][0][0][0][0][0]

pr_data_01 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.1.mat')
precision['0.1'] = pr_data_01['precision'][0][0][0][0]
recall['0.1'] = pr_data_01['recall'][0][0][0][0]
average_precision['0.1'] = pr_data_01['average_precision'][0][0][0][0][0]

pr_data_02 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.2.mat')
precision['0.2'] = pr_data_02['precision'][0][0][0][0]
recall['0.2'] = pr_data_02['recall'][0][0][0][0]
average_precision['0.2'] = pr_data_02['average_precision'][0][0][0][0][0]

pr_data_03 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.3.mat')
precision['0.3'] = pr_data_03['precision'][0][0][0][0]
recall['0.3'] = pr_data_03['recall'][0][0][0][0]
average_precision['0.3'] = pr_data_03['average_precision'][0][0][0][0][0]

pr_data_04 = sio.loadmat('/root/WorkSpace/project/spectrum_two_stage/results/precision_recall_Co-60_0.4.mat')
precision['0.4'] = pr_data_04['precision'][0][0][0][0]
recall['0.4'] = pr_data_04['recall'][0][0][0][0]
average_precision['0.4'] = pr_data_04['average_precision'][0][0][0][0][0]
for key in precision.keys():
    plt.plot(
        recall[key],
        precision[key],
        label=f"PR curve (AP = {average_precision[key]:.2f} $\lambda_n$ = {key}) ",
        linewidth=1,
    )
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.title('Micro-average Precision-Recall curve under different $\lambda_n$')
plt.savefig('/root/WorkSpace/project/spectrum_two_stage/results/pr_curve.png',dpi=300)
plt.close()

# %%
# plot average f1 score
import matplotlib.pyplot as plt

f1 = dict()
f1['0.05'] = 0.4221
f1['0.06'] = 0.3632
f1['0.07'] = 0.2913
f1['0.08'] = 0.2789
f1['0.09'] = 0.2272
f1['0.1'] = 0.2261
f1['0.2'] = 0.1045
f1['0.3'] = 0.0572
f1['0.4'] = 0.0362
keys = list(f1.keys())
values = list(f1.values())

colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'orange', 'purple']
labels = [f"$F_1$ = {value:.4f}" for value in values]

for key, value, color, label in zip(keys, values, colors, labels):
    plt.plot(
        key,
        value,
        marker='^',
        linestyle='-',
        color=color,
        label=label,
    )

plt.xlabel('$\lambda_n$')
plt.ylabel('F1 score')
plt.title('Macro Average F1 score under different $\lambda_n$')
plt.legend()
plt.savefig('/root/WorkSpace/project/spectrum_two_stage/results/f1_score.png', dpi=300)
plt.close()
